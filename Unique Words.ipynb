# %%
import nltk as nl

# %%
nokia_reviews = nl.corpus.product_reviews_1.words("Nokia_6610.txt")

# %%
nokia_reviews_fd = nl.FreqDist(nokia_reviews)

# %%
nokia_reviews_fd
# Out:
# FreqDist({'.': 490, 'the': 442, ',': 351, 'i': 267, 'phone': 211, 'to': 210, 'and': 195, 'is': 189, 'a': 187, 'it': 166, ...})

# %%
nokia_reviews_fd.most_common(5)
# Out:
# [('.', 490), ('the', 442), (',', 351), ('i', 267), ('phone', 211)]

# %%
nokia_reviews_fd.hapaxes()
# Out:
# ['business',
#  'depend',
#  'box',
#  'double',
#  'ensure',
#  'city',
#  'exchange',
#  'torture',
#  'delighted',
#  'forward',
#  'august',
#  '2004',
#  'convert',
#  'recent',
#  'northern',
#  'kentucky',
#  'cincinnati',
#  'experienced',
#  '75',
#  'stretches',
#  'route',
#  'panasonic',
#  '8',
#  'generally',
#  'prefer',
#  'combines',
#  'missing',
#  'recognition',
#  'audible',
#  'freeway',
#  'noise',
#  'blessing',
#  'saved',
#  'entering',
#  'portability',
#  'seemed',
#  'heaven',
#  'sent',
#  'eyed',
#  'gave',
#  'whirl',
#  'synopsis',
#  'feels',
#  'plastic',
#  'sturdy',
#  'pim',
#  'manager',
#  'accepts',
#  '13',
#  '14',
#  'believe',
#  'unpredictable',
#  'plugged',
#  'tedious',
#  'hurts',
#  'ears',
#  'backgrounds',
#  'screensavers',
#  'memory',
#  '230kb',
#  'crisp',
#  'liked',
#  'serves',
#  'purpose',
#  'backlight',
#  'goes',
#  'dangerous',
#  'driving',
#  'checked',
#  'fingertips',
#  'uncreative',
#  'items',
#  'pick',
# ...
